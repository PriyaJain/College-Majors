# %%
import pandas as pd
import numpy as np
from pandas import DataFrame,Series
from __future__ import division

# %%
ages=pd.read_csv("all-ages.csv")
r_g=pd.read_csv("recent-grads.csv")

# %%
# This data gives us the employment data for all ages
ages.head()
# Out:
#    Major_code                                  Major  \
# 0        1100                    GENERAL AGRICULTURE
# 1        1101  AGRICULTURE PRODUCTION AND MANAGEMENT
# 2        1102                 AGRICULTURAL ECONOMICS
# 3        1103                        ANIMAL SCIENCES
# 4        1104                           FOOD SCIENCE
#
#                     Major_category   Total  Employed  \
# 0  Agriculture & Natural Resources  128148     90245
# 1  Agriculture & Natural Resources   95326     76865
# 2  Agriculture & Natural Resources   33955     26321
# 3  Agriculture & Natural Resources  103549     81177
# 4  Agriculture & Natural Resources   24280     17281
#
#    Employed_full_time_year_round  Unemployed  Unemployment_rate  Median  \
# 0                          74078        2423           0.026147   50000
# 1                          64240        2266           0.028636   54000
# 2                          22810         821           0.030248   63000
# ...

# %%
#This data gives us the employment data for recent grads.
r_g.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed      ...        \
# 0   2339           36   2057    282    0.120564      1976      ...
# 1    756            7    679     77    0.101852       640      ...
# 2    856            3    725    131    0.153037       648      ...
# 3   1258           16   1123    135    0.107313       758      ...
# 4  32260          289  21239  11021    0.341631     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
'''We will be answering the following questions using these two datsets:
1) How many students are there in each Major_category in both datasets
2) What % of recent grads have low wage jobs
3) Are there any particular majors in which recent grads fare better than over all population?'''
# Out:
# 'We will be answering the following questions using these two datsets:\n1) How many students are there in each Major_category in both datasets\n2) What % of recent grads have low wage jobs\n3) Are there any particular majors in which recent grads fare better than over all population?'

# %%
# number of students across all ages in each major_category
ages["Major_category"].value_counts()
# Out:
# Engineering                            29
# Education                              16
# Humanities & Liberal Arts              15
# Biology & Life Science                 14
# Business                               13
# Health                                 12
# Computers & Mathematics                11
# Physical Sciences                      10
# Agriculture & Natural Resources        10
# Psychology & Social Work                9
# Social Science                          9
# Arts                                    8
# Industrial Arts & Consumer Services     7
# Law & Public Policy                     5
# Communications & Journalism             4
# Interdisciplinary                       1
# Name: Major_category, dtype: int64

# %%
# number of recent grads in each major_category
r_g_maj_cat=r_g["Major_category"].value_counts()

# %%
# Make a dict of the above

# %%
r_g_maj_cat_dict=dict(r_g_maj_cat)
r_g_maj_cat_dict
# Out:
# {'Agriculture & Natural Resources': 10,
#  'Arts': 8,
#  'Biology & Life Science': 14,
#  'Business': 13,
#  'Communications & Journalism': 4,
#  'Computers & Mathematics': 11,
#  'Education': 16,
#  'Engineering': 29,
#  'Health': 12,
#  'Humanities & Liberal Arts': 15,
#  'Industrial Arts & Consumer Services': 7,
#  'Interdisciplinary': 1,
#  'Law & Public Policy': 5,
#  'Physical Sciences': 10,
#  'Psychology & Social Work': 9,
#  'Social Science': 9}

# %%
total_low_wage=r_g["Low_wage_jobs"].sum()
total_grads=r_g['Total'].sum()

low_wage_prop=((total_low_wage / total_grads)*100)

# %%
total_low_wage
# Out:
# 667610

# %%
total_grads
# Out:
# 6776015

# %%
low_wage_prop
# Out:
# 9.852546076122913

# %%
ages.columns
# Out:
# Index([u'Major_code', u'Major', u'Major_category', u'Total', u'Employed',
#        u'Employed_full_time_year_round', u'Unemployed', u'Unemployment_rate',
#        u'Median', u'P25th', u'P75th'],
#       dtype='object')

# %%
r_g.columns
# Out:
# Index([u'Rank', u'Major_code', u'Major', u'Major_category', u'Total',
#        u'Sample_size', u'Men', u'Women', u'ShareWomen', u'Employed',
#        u'Full_time', u'Part_time', u'Full_time_year_round', u'Unemployed',
#        u'Unemployment_rate', u'Median', u'P25th', u'P75th', u'College_jobs',
#        u'Non_college_jobs', u'Low_wage_jobs'],
#       dtype='object')

# %%
ages_short=ages.drop(["Employed_full_time_year_round"],axis=1)

# %%
r_g_short=r_g[ages_short.columns]

# %%
# This data set has only those cols which are common with ages data.

r_g_short
# Out:
#      Major_code                                          Major  \
# 0          2419                          PETROLEUM ENGINEERING
# 1          2416                 MINING AND MINERAL ENGINEERING
# 2          2415                      METALLURGICAL ENGINEERING
# 3          2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4          2405                           CHEMICAL ENGINEERING
# 5          2418                            NUCLEAR ENGINEERING
# 6          6202                              ACTUARIAL SCIENCE
# 7          5001                     ASTRONOMY AND ASTROPHYSICS
# 8          2414                         MECHANICAL ENGINEERING
# 9          2408                         ELECTRICAL ENGINEERING
# 10         2407                           COMPUTER ENGINEERING
# 11         2401                          AEROSPACE ENGINEERING
# 12         2404                         BIOMEDICAL ENGINEERING
# 13         5008                              MATERIALS SCIENCE
# ...

# %%
r_g_short['Unemployment_rate'].mean()
# Out:
# 0.06858728923255816

# %%
ages['Unemployment_rate'].mean()
# Out:
# 0.05735545328323702

# %%
''' Find the names of majors in which unemployment rate is lower for recent grads than for all ages'''
# Out:
# 'let us find the names of majors in which unemployment rate is lower for recent grads than for aall ages'

# %%
r_g_maj=r_g["Major"].loc[r_g["Unemployment_rate"] > ages['Unemployment_rate']]

# %%
r_g_maj
# Out:
# 1                         MINING AND MINERAL ENGINEERING
# 3              NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                                   CHEMICAL ENGINEERING
# 5                                    NUCLEAR ENGINEERING
# 6                                      ACTUARIAL SCIENCE
# 8                                 MECHANICAL ENGINEERING
# 9                                 ELECTRICAL ENGINEERING
# 10                                  COMPUTER ENGINEERING
# 12                                BIOMEDICAL ENGINEERING
# 15                                BIOLOGICAL ENGINEERING
# 18                             ARCHITECTURAL ENGINEERING
# 20                                      COMPUTER SCIENCE
# 21                                          FOOD SCIENCE
# 22                     ELECTRICAL ENGINEERING TECHNOLOGY
# 24         MANAGEMENT INFORMATION SYSTEMS AND STATISTICS
# 25                                     CIVIL ENGINEERING
# ...

# %%
# number of majors where unemploymnet rate was higher for recent grads

len(r_g_maj.unique())
# Out:
# 108
